# %% [markdown]
# # Age Dection with FASTAI
#
# ## Prediction

# %%
#As of 04/30/2020 there is a FASTAI issue with Pytorch 1.5 so the line below installs older versions.
#So do this first, restart kernel and start working. 
# !pip install torch===1.4.0 torchvision===0.5.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 753.4MB 20kB/s
# ...
#      |████████████████████████████████| 4.0MB 45.8MB/s
# ...
#   Found existing installation: torch 1.5.0+cu101
#     Uninstalling torch-1.5.0+cu101:
#       Successfully uninstalled torch-1.5.0+cu101
#   Found existing installation: torchvision 0.6.0+cu101
#     Uninstalling torchvision-0.6.0+cu101:
#       Successfully uninstalled torchvision-0.6.0+cu101
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from google.colab import drive

# %%
drive.mount("Docs")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at Docs

# %%
learn = load_learner("/content/Docs/My Drive/models/")

# %%
img = open_image("/content/Docs/My Drive/toddler.jpeg")
img.show()

# %%
learn.predict(img)
# Out:
# (Category (0, 2),
#  tensor(0),
#  tensor([9.1138e-01, 1.8586e-05, 9.3646e-04, 1.8139e-05, 7.2351e-02, 3.1071e-05,
#          1.3632e-02, 1.6295e-03]))

# %%
img = open_image("/content/Docs/My Drive/older.jpeg")
img.show()

# %%
learn.predict(img)
# Out:
# (Category (48, 53),
#  tensor(5),
#  tensor([1.1004e-09, 2.5220e-12, 9.0590e-08, 6.7412e-05, 4.9513e-11, 9.9591e-01,
#          4.0174e-03, 1.7271e-10]))

# %%
img = open_image("/content/Docs/My Drive/older3.jpeg")
img.show()

# %%
learn.predict(img)
# Out:
# (Category (15, 20),
#  tensor(1),
#  tensor([3.9294e-03, 4.4916e-01, 1.4559e-02, 1.7314e-02, 1.3858e-01, 2.7228e-02,
#          8.3713e-05, 3.4915e-01]))

# %%
img = open_image("/content/Docs/My Drive/older4.jpeg")
img.show()

# %%
age, _ , _ = learn.predict(img)
age
# Out:
# Category (60, 100)
